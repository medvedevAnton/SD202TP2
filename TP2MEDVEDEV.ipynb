# %% [markdown]
# # TP2 - DB Normalization and Querying
#
# The objectives of this TP are:
# 1. Apply normalization 1NF -> 2NF -> 3NF
# 2. Perform SQL queries on the normalized database
#
# In this TP, we will use a database **`wine.db`** (available in the course's website) containing wine information related to 'production' and 'sales'.
#
# > Production <---> Wine <---> Sales
#
#
# ---
#
# ### Working with db files in Jupyter
# - Python provides an interface for SQLite through the *sqlite3* module
# - The **`%%sql`** magic builds upon it (and other tools) to enable the usage of SQL commands within a Jupyter Notebook as in common SQL clients.
# - Before proceeding, make sure that **`wine.db`** is in the same path as this notebook.
#   - If **`wine.db`** is not in the same path, an empty **`wine.db`** file will be created, resulting in errors in later steps of the TP.
# - The SQLite module in Python commits transactions automatically, this means that any change in the DB is immediately written to the file, e.g. creating/deleting tables.
#   -  For this reason, it is recommended to have a backup of **`wine.db`** as it is provided in the course's website.
#
# ---

# %% [markdown]
# **`wine.db`** contains the following unnormalized tables:
#
# <center> **Master1** </center>
#
# |*Attribute*|         *Description*          |
# | -------   |--------------------------------|
# | NV        | Wine number                    |
# | CRU       | Vineyard or group of vineyards |
# | DEGRE     | Alcohol content                |
# | MILL      | Vintage year                   |
# | QTE       | Number of bottles harvested    |
# | NP        | Producer number                |
# | NOM       | Producer's last name           |
# | PRENOM    | Producer's first name          |
# | REGION    | Production region              |
#
# From wikipedia:
#
# __Cru__: Often used to indicate a specifically named and legally defined vineyard or ensemble of vineyards and the vines "which grow on [such] a reputed terroir; by extension of good quality." The term is also used to refer to the wine produced from such vines.
#
#
# <center>**Master2**</center>
#
# |*Attribute*|                         *Description*                  |
# | -------   |--------------------------------------------------------|
# | NV        | Wine number                                            |
# | CRU       | Vineyard or group of vineyards                         |
# | DEGRE     | Alcohol content                                        |
# | MILL      | Vintage year                                           |
# | DATES     | Buying date                                            |
# | LIEU      | Place where the wine was sold                          |
# | QTE       | Number of bottles bought                               |
# | NB        | Client (buveur) number                                 |
# | NOM       | Client's last name                                     |
# | PRENOM    | Client's first name                                    |
# | TYPE      | Type of client by volume of purchases                  |
# | REGION    | Administrative Region (different to production region) |

# %%
import sqlite3    # Python interface for SQLite databases

# %%
def printSchema(connection):
    # Function to print the DB schema
    # Source: http://stackoverflow.com/a/35092773/4765776
    for (tableName,) in connection.execute(
        """
        select NAME from SQLITE_MASTER where TYPE='table' order by NAME;
        """
    ):
        print("{}:".format(tableName))
        for (
            columnID, columnName, columnType,
            columnNotNull, columnDefault, columnPK,
        ) in connection.execute("pragma table_info('{}');".format(tableName)):
            print("  {id}: {name}({type}){null}{default}{pk}".format(
                id=columnID,
                name=columnName,
                type=columnType,
                null=" not null" if columnNotNull else "",
                default=" [{}]".format(columnDefault) if columnDefault else "",
                pk=" *{}".format(columnPK) if columnPK else "",
            ))

# %%
conn = sqlite3.connect('wine.db')
c = conn.cursor()
print("Database schema:")
printSchema(conn)           # An usefull way to viualize the content of the database
# Out:
# Database schema:
# MASTER1:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
#   4: QTE(NUM)
#   5: NP(NUM)
#   6: NOM(TEXT)
#   7: PRENOM(TEXT)
#   8: REGION(TEXT)
# MASTER2:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
#   4: DATES(DATE)
#   5: LIEU(TEXT)
#   6: QTE(NUM)
#   7: NB(NUM)
#   8: NOM(TEXT)
#   9: PRENOM(TEXT)
#   10: TYPE(TEXT)
#   11: REGION(TEXT)
# achats:
#   0: NB(NUM)
#   1: NV(NUM)
#   2: LIEU(TEXT)
#   3: DATES(NUM)
#   4: QTE(NUM)
# acheteurs:
#   0: NB(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: TYPE(TEXT)
# lieu:
#   0: LIEU(TEXT)
#   1: REGION(TEXT)
# producteur:
#   0: NP(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: REGION(TEXT)
# produits:
#   0: NV(NUM)
#   1: NP(NUM)
#   2: QTE(NUM)
# vins:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
# vins1:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
# vins2:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)

# %% [markdown]
# From this point we will use __%%sql__ magic

# %%
# %load_ext sql
# %sql sqlite:///wine.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# u'Connected: @wine.db'

# %% [markdown]
# # PART I: Database normalization

# %% [markdown]
# The first task on this TP is the normalization of the wine data. In its current state both tables **Master1** and **Master2** are in the First Normal Form (1NF).
#
# By inspecting the content of these tables we can see that multiple tuples have NULL values.

# %%
# %%sql SELECT *
# FROM Master1
# LIMIT 100;
# Out:
#  * sqlite:///wine.db
# Done.
# [(None, None, None, None, None, 3, u'Six', u'Paul', u'Alsace'),
#  (None, None, None, None, None, 6, u'Marmagne', u'Bernard', u'Bourgogne'),
#  (None, None, None, None, None, 8, u"Lioger d'Harduy", u'Gabriel', u'Bourgogne'),
#  (None, None, None, None, None, 16, u'Barbin', u'Bernard', u'Bourgogne'),
#  (None, None, None, None, None, 17, u'Faiveley', u'Guy', u'Bourgogne'),
#  (None, None, None, None, None, 18, u'Tramier', u'Jean', u'Bourgogne'),
#  (None, None, None, None, None, 19, u'Dupaquier', u'Roger', u'Bourgogne'),
#  (None, None, None, None, None, 20, u'Lamy', u'Jean', u'Bourgogne'),
#  (None, None, None, None, None, 21, u'Cornu', u'Edmond', u'Bourgogne'),
#  (None, None, None, None, None, 26, u'Violot', u'Gilbert', u'Bourgogne'),
#  (None, None, None, None, None, 28, u'Monnier', u'Rene', u'Bourgogne'),
#  (None, None, None, None, None, 29, u'de Suremain', u'Robert', u'Bourgogne'),
#  (None, None, None, None, None, 31, u'Prudhon', u'Henri', u'Bourgogne'),
#  (None, None, None, None, None, 32, u'Mestre', u'Philippe', u'Bourgogne'),
#  (20, u'Cote de Brouilly', 12.1, 1980, 100, 50, u'Chagny', u'Georges', u'Bourgogne'),
#  (21, u'Cotes de Nuits', None, 1978, 150, 5, u'Joudeat', u'Lucien', u'Bourgogne'),
#  (22, u'Savigny les Beaunes', None, 1974, 50, 86, u'Dumazet', u'Marc', u'Rhone'),
#  (23, u'Pommard', None, 1972, 15, 86, u'Dumazet', u'Marc', u'Rhone'),
#  (24, u'Cotes de Beaune Villages', 12.1, 1971, 859, 36, u'Sauzet', u'Etienne', u'Bourgogne'),
#  (25, u'Chapelle Chambertin', 10.5, 1968, 40, 95, u'Verset', u'Louis', u'Rhone'),
#  (26, u'Chateau Corton Grancey', None, 1980, 70, 43, u'Menand', u'Jean Claude', u'Bourgogne'),
#  (27, u'Puligny Montrachet', 11, 1974, 60, 99, u'Cooperative', None, u'Rhone'),
#  (28, u'Volnay', 11, 1980, 10, 50, u'Chagny', u'Georges', u'Bourgogne'),
#  (29, u'Corton', 11.6, 1972, 50, 50, u'Chagny', u'Georges', u'Bourgogne'),
#  (30, u'Bourgogne Passe Tout Grains', 12, 1979, 350, 22, u'Dubreuil Fontaine', u'Pierre', u'Bourgogne'),
#  (31, u'Monthelie', 11.4, 1968, 320, 50, u'Chagny', u'Georges', u'Bourgogne'),
#  (32, u'Pouilly Vinzelles', 12.3, 1968, 500, 9, u'Moniot', u'Gilbert', u'Bourgogne'),
#  (32, u'Pouilly Vinzelles', 12.3, 1968, 890, 72, u'Reverchon', u'Joseph', u'Jura')]

# %% [markdown]
# * Notice that Jupyter *displays* 'None' instead of 'NULL'.
#   - This is only to comply with python notation.
# * To account for NULL values, your SQL queries must test explicitly for 'NULL'.
#
# Another problem in **Master1** and **Master2** is data redundancy, for example:

# %%
# %%sql SELECT *
# FROM Master2;
# Out:
#  * sqlite:///wine.db
# Done.
# [(None, None, None, None, None, None, None, 11, u'Breton', u'Andre', u'petit', None),
#  (None, None, None, None, None, None, None, 13, u'Barthes', u'Roland', u'moyen', None),
#  (None, None, None, None, None, None, None, 16, u'Balzac', u'Honore de', u'moyen', None),
#  (None, None, None, None, None, None, None, 18, u'Celine', u'Louis Ferdinand', u'gros', None),
#  (None, None, None, None, None, None, None, 20, u'Chateaubriand', u'Francois-Rene de', u'moyen', None),
#  (None, None, None, None, None, None, None, 21, u'Corbiere', u'Tristan', u'petit', None),
#  (None, None, None, None, None, None, None, 23, u'Corneille', u'Pierre', u'petit', None),
#  (None, None, None, None, None, None, None, 25, u'Char', u'Rene', u'petit', None),
#  (None, None, None, None, None, None, None, 27, u'Dumas', u'Alexandre', u'gros', None),
#  (None, None, None, None, None, None, None, 29, u'Fournier', u'Alain', u'petit', None),
#  (None, None, None, None, None, None, None, 32, u'Eluard', u'Paul', u'moyen', None),
#  (None, None, None, None, None, None, None, 34, u'Mauriac', u'Francois', u'petit', None),
#  (None, None, None, None, None, None, None, 35, u'Fromentin', u'Eugene', u'gros', None),
#  (None, None, None, None, None, None, None, 36, u'Maurois', u'Andre', u'petit', None),
#  (101, u'Saint Veran', 12.5, 1973, None, None, None, None, None, None, None, None),
#  (107, u'Sancerre', 14, 1998, None, None, None, None, None, None, None, None)]

# %% [markdown]
# ---
#
# Additional resource for Normalization:
#
# https://www.youtube.com/watch?v=UrYLYV7WSHM
#
# ---

# %% [markdown]
# #### Exercise 1.1
#
# Convert table **Master1** to the Second Normal Form (2NF) or Third Normal Form (3NF) as applicable.
# * Explain your answer
# * List main functional dependencies (not all of them)
# * Describe the schema of new tables and how they relate
#   * You can write Tables as above or you can insert images in the notebook.
#
# Remember that **`wine.db`** contains information related to wine 'production' and 'sells'.
#
# > Production <---> Wine <---> Sales
#
# A good start point is to look for the 'Wine' attributes.
#
# **Hint:** Look for redundant information between the master tables.

# %% [markdown]
# <img src="./question1.jpeg">
# <img src="./question1.2.jpeg">

# %% [markdown]
# #### Exercise 1.2
#
# Convert table **Master2** to the Second Normal Form (2NF) or Third Normal Form (3NF) as applicable.
# * Explain your answer
# * List main functional dependencies (not all of them)
# * Describe the schema of new tables and how they relate
#   * You can write Tables as above or you can insert images in the notebook.
#
# **Note:** For this part, consider that a wine can be bought in multiple locations and multiple times per day.

# %% [markdown]
# <img src="./question2.jpeg">

# %% [markdown]
# Once you have defined the 2NF or 3NF (as applicable) we need to split the data into new tables.
#
# A table can be created from the result of a query.
#
# In the following example we will create a new table "dummy" to store the different values of alcohol content.

# %%
# %%sql DROP TABLE IF EXISTS dummy;
#
# -- Create dummy table
# CREATE TABLE dummy AS
# SELECT DISTINCT DEGRE
# FROM MASTER1;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# []

# %%
print("\nContent of the database")
printSchema(conn)
# Out:
# Content of the database
# MASTER1:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
#   4: QTE(NUM)
#   5: NP(NUM)
#   6: NOM(TEXT)
#   7: PRENOM(TEXT)
#   8: REGION(TEXT)
# MASTER2:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
#   4: DATES(DATE)
#   5: LIEU(TEXT)
#   6: QTE(NUM)
#   7: NB(NUM)
#   8: NOM(TEXT)
#   9: PRENOM(TEXT)
#   10: TYPE(TEXT)
#   11: REGION(TEXT)
# achats:
#   0: NB(NUM)
#   1: NV(NUM)
#   2: LIEU(TEXT)
#   3: DATES(NUM)
#   4: QTE(NUM)
# acheteurs:
#   0: NB(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: TYPE(TEXT)
# dummy:
#   0: DEGRE(NUM)
# lieu:
#   0: LIEU(TEXT)
#   1: REGION(TEXT)
# producteur:
#   0: NP(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: REGION(TEXT)
# produits:
#   0: NV(NUM)
#   1: NP(NUM)
#   2: QTE(NUM)
# vins:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
# vins1:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
# vins2:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)

# %%
# %%sql
# SELECT *
# FROM dummy;
# Out:
#  * sqlite:///wine.db
# Done.
# [(None,),
#  (11.5,),
#  (11.3,),
#  (12.1,),
#  (10.9,),
#  (11.7,),
#  (11.2,),
#  (12.3,),
#  (11.9,),
#  (11.8,),
#  (10.7,),
#  (11.4,),
#  (10.5,),
#  (11,),
#  (11.6,),
#  (12,),
#  (10,),
#  (12.5,),
#  (10.8,),
#  (14,),
#  (11.1,),
#  (13,)]

# %% [markdown]
# Looking into "dummy", we notice that our query includes NULL. This is not allowed if we were to use DEGRE as key for a table.
#
# To correct this, we need to change the query to explicitly test for NULL as follows:

# %%
# %%sql DROP TABLE IF EXISTS dummy;
#
# -- Create dummy table
# CREATE TABLE dummy AS
# SELECT DISTINCT DEGRE
# FROM MASTER1
# WHERE DEGRE IS NOT NULL;
#
# SELECT *
# FROM dummy;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(11.5,),
#  (11.3,),
#  (12.1,),
#  (10.9,),
#  (11.7,),
#  (11.2,),
#  (12.3,),
#  (11.9,),
#  (11.8,),
#  (10.7,),
#  (11.4,),
#  (10.5,),
#  (11,),
#  (11.6,),
#  (12,),
#  (10,),
#  (12.5,),
#  (10.8,),
#  (14,),
#  (11.1,),
#  (13,)]

# %% [markdown]
# Notice that we use `NULL` given that `None` is only used for display.

# %%
# Remove "dummy" table
# %sql DROP TABLE IF EXISTS dummy;
# Out:
#  * sqlite:///wine.db
# Done.
# []

# %% [markdown]
# #### Exercise 1.3
#
# Create the new tables from Master1:

# %%
# %%sql DROP TABLE IF EXISTS producteur;
#
# CREATE TABLE producteur AS
# SELECT DISTINCT NP, NOM, PRENOM, REGION
# FROM MASTER1 WHERE NP IS NOT NULL;
#
# SELECT *
# FROM producteur;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(3, u'Six', u'Paul', u'Alsace'),
#  (6, u'Marmagne', u'Bernard', u'Bourgogne'),
#  (8, u"Lioger d'Harduy", u'Gabriel', u'Bourgogne'),
#  (16, u'Barbin', u'Bernard', u'Bourgogne'),
#  (17, u'Faiveley', u'Guy', u'Bourgogne'),
#  (18, u'Tramier', u'Jean', u'Bourgogne'),
#  (19, u'Dupaquier', u'Roger', u'Bourgogne'),
#  (20, u'Lamy', u'Jean', u'Bourgogne'),
#  (21, u'Cornu', u'Edmond', u'Bourgogne'),
#  (26, u'Violot', u'Gilbert', u'Bourgogne'),
#  (28, u'Monnier', u'Rene', u'Bourgogne'),
#  (29, u'de Suremain', u'Robert', u'Bourgogne'),
#  (31, u'Prudhon', u'Henri', u'Bourgogne'),
#  (32, u'Mestre', u'Philippe', u'Bourgogne'),
#  (33, u'Prieur', u'Guy', u'Bourgogne'),
#  (34, u'Monnier', u'Rene', u'Bourgogne'),
#  (37, u'Delagrange Bachelet', None, u'Bourgogne'),
#  (39, u'de Suremin', u'Hugues', u'Bourgogne'),
#  (41, u'Juillot', u'Michel', u'Bourgogne'),
#  (44, u'Feyveley', None, u'Bourgogne'),
#  (65, u'Rochgrande', 10.8, 1968),
#  (66, u'Tavel', 11, 1968),
#  (67, u'Gewurztraminer', 12.5, 1968),
#  (68, u'Riesling', 14, 1962),
#  (69, u"Tokay d'Alsace", 11, 1982),
#  (70, u'Sylvaner', 11, 1982),
#  (71, u'Palette', 11, 1981),
#  (72, u'Cassis', 10, 1978),
#  (73, u'Bellet', 11, 1976),
#  (74, u'Arbois', 12, 1980),
#  (75, u'Arbois', 11, 1976),
#  (76, u'Chateau Chalon', 12, 1976),
#  (77, u'Etoile', 11, 1979),
#  (78, u'Etoile', 12, 1980),
#  (79, u'Seyssel', 11, 1980),
#  (80, u'Seyssel', 11, 1980),
#  (81, u'Cornas', 11.1, 1980),
#  (82, u'Cornas', 11, 1980),
#  (83, u'Saint Amour', 10, 1980),
#  (84, u'Rasteau', 10, 1980),
#  (85, u'Tavel', 11, 1980),
#  (86, u'Tavel', 11, 1980),
#  (87, u'Cotes de Provence', None, 1980),
#  (88, u'Cotes de Provence', 10, 1976),
#  (89, u'Cotes de Provence', 11, 1969),
#  (90, u'Palette', 11, 1969),
#  (91, u'Cassis', 11, 1979),
#  (92, u'Coteaux de Pierevert', None, 1967),
#  (93, u'Blanquette de Limoux', None, 1978),
#  (94, u'Cotes du Rousillon', None, 1978),
#  (95, u'Cotes du Rousillon', 12, 1978),
#  (96, u'Saint Chinian', 11, 1976),
#  (97, u'Saint Chinian', 11, 1976),
#  (98, u'Corbieres', 10, 1978),
#  (99, u'Cote Rotie', 13, 1994),
#  (100, u'Seyssel', 11, 1974),
#  (101, u'Saint Veran', 12.5, 1973),
#  (107, u'Sancerre', 14, 1998)]

# %%
# %%sql DROP TABLE IF EXISTS produits;
#
# CREATE TABLE produits AS
# SELECT NV, NP, QTE
# FROM MASTER1 WHERE NV IS NOT NULL AND NP IS NOT NULL;
#
#
# SELECT *
# FROM produits;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(1, 1, 300),
#  (1, 73, 1),
#  (2, 5, 100),
#  (3, 1, 400),
#  (4, 10, 35),
#  (5, 30, 46),
#  (6, 42, 300),
#  (7, 98, 60),
#  (8, 90, 12),
#  (10, 98, 100),
#  (11, 5, 200),
#  (12, 7, 31),
#  (12, 43, 200),
#  (12, 89, 310),
#  (13, 13, 13),
#  (14, 86, 180),
#  (15, 80, 290),
#  (16, 38, 100),
#  (17, 95, 50),
#  (18, 40, 120),
#  (19, 7, 986),
#  (20, 50, 100),
#  (21, 5, 150),
#  (22, 86, 50),
#  (23, 86, 15),
#  (24, 36, 859),
#  (25, 95, 40),
#  (26, 43, 70),
#  (27, 99, 60),
#  (28, 50, 10),
#  (29, 50, 50),
#  (30, 22, 350),
#  (31, 50, 320),
#  (32, 9, 500),
#  (32, 72, 890),
#  (33, 60, 70),
#  (34, 4, None),
#  (35, 10, 900),
#  (35, 23, 350),
#  (36, 93, 50),
#  (37, 54, 830),
#  (38, 52, 125),
#  (39, 52, 80),
#  (41, 76, 25),
#  (42, 82, 80),
#  (43, 13, 500),
#  (43, 72, 900),
#  (43, 85, 983),
#  (44, 93, 40),
#  (45, 2, 90),
#  (45, 67, 912),
#  (45, 71, 98),
#  (45, 78, 540),
#  (45, 86, 450),
#  (46, 64, 760),
#  (47, 52, 75),
#  (48, 93, 70),
#  (49, 2, 150),
#  (50, 2, 100),
#  (51, 15, 36),
#  (52, 40, 500),
#  (53, 40, 800),
#  (54, 1, 500),
#  (54, 2, 900),
#  (54, 14, 500),
#  (55, 14, 450),
#  (56, 24, 790),
#  (57, 40, 940),
#  (58, 45, 70),
#  (59, 45, 160),
#  (60, 50, 300),
#  (60, 60, 60),
#  (61, 90, 120),
#  (62, 60, 900),
#  (64, 72, 870),
#  (64, 85, 980),
#  (65, 12, 10),
#  (65, 25, 560),
#  (67, 5, 125),
#  (67, 10, 890),
#  (67, 82, 760),
#  (68, 12, None),
#  (69, 9, 96),
#  (69, 12, 320),
#  (69, 69, 690),
#  (70, 38, 120),
#  (71, 38, 132),
#  (72, 52, 34),
#  (73, 38, 45),
#  (74, 70, 650),
#  (74, 72, 850),
#  (74, 84, 675),
#  (75, 38, 69),
#  (76, 46, 100),
#  (76, 85, 900),
#  (77, 85, 100),
#  (78, 4, 300),
#  (78, 27, 360),
#  (78, 30, 900),
#  (78, 68, 980),
#  (78, 80, 970),
#  (79, 74, 100),
#  (79, 79, 79),
#  (79, 81, 800),
#  (80, 90, 79),
#  (81, 90, 24),
#  (82, 43, 100),
#  (82, 80, 800),
#  (83, 95, 423),
#  (84, 95, 146),
#  (85, 55, 46),
#  (86, 93, 500),
#  (87, 38, 630),
#  (87, 45, 680),
#  (87, 72, 900),
#  (88, 55, 129),
#  (89, 15, 150),
#  (89, 42, 980),
#  (89, 55, 723),
#  (89, 89, 100),
#  (90, 56, 900),
#  (90, 95, 40),
#  (91, 79, 24),
#  (92, 11, 900),
#  (93, 79, 110),
#  (94, 11, 500),
#  (94, 27, 180),
#  (95, 95, 900),
#  (96, 59, 370),
#  (97, 70, 101),
#  (98, 24, 986),
#  (98, 35, 400),
#  (98, 75, 150),
#  (98, 76, 890),
#  (98, 88, 340),
#  (99, 5, 100),
#  (99, 99, 199),
#  (100, 25, 100),
#  (101, 70, 213),
#  (107, 107, 7000)]

# %% [markdown]
# #### Exercise 1.4
#
# Create the new tables from Master2:

# %%
# %%sql DROP TABLE IF EXISTS acheteurs;
#
# CREATE TABLE acheteurs AS
# SELECT DISTINCT NB, NOM, PRENOM, TYPE
# FROM MASTER2 WHERE NB IS NOT NULL;
#
#
# SELECT *
# FROM acheteurs;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(11, u'Breton', u'Andre', u'petit'),
#  (13, u'Barthes', u'Roland', u'moyen'),
#  (16, u'Balzac', u'Honore de', u'moyen'),
#  (18, u'Celine', u'Louis Ferdinand', u'gros'),
#  (20, u'Chateaubriand', u'Francois-Rene de', u'moyen'),
#  (21, u'Corbiere', u'Tristan', u'petit'),
#  (23, u'Corneille', u'Pierre', u'petit'),
#  (25, u'Char', u'Rene', u'petit'),
#  (27, u'Dumas', u'Alexandre', u'gros'),
#  (29, u'Fournier', u'Alain', u'petit'),
#  (58, u'Marivaux', u'Pierre Carlet de Chamblain de', u'gros'),
#  (1, u'Aristote', None, u'petit'),
#  (9, u'Ajar', u'Emile', u'petit'),
#  (60, u'Ovide', None, u'gros'),
#  (5, u'Audiberti', u'Jacques', u'petit'),
#  (10, u'Andersen', u'Yann', u'gros'),
#  (61, u'Mallarme', u'Stephane', u'petit'),
#  (6, u'Arrabal', u'Fernando', u'gros'),
#  (62, u'Proust', u'Marcel', u'moyen'),
#  (75, u'Ronsard', u'Pierre', u'moyen'),
#  (80, u'Sand', u'Georges', u'petit'),
#  (82, u'Roussel', u'Rene', u'petit'),
#  (100, u'Woolf', u'Virginia', u'petit'),
#  (26, u'Diderot', u'Denis', u'moyen'),
#  (28, u'Dostoievsky', u'Fiodor', u'gros'),
#  (22, u'Cocteau', u'Jean', u'gros'),
#  (24, u'Courrier', u'Paul Louis', u'moyen'),
#  (30, u'La Fontaine', u'Jean de', u'petit'),
#  (12, u'Bataille', u'Georges', u'moyen'),
#  (14, u'Bory', u'Jean Louis', u'gros'),
#  (15, u'Baudelaire', u'Charles', u'petit'),
#  (17, u'Camus', u'Albert', u'petit'),
#  (19, u'Ciceron', None, u'gros'),
#  (33, u'Flaubert', u'Gustave', u'moyen'),
#  (92, u'Verne', u'Jules', u'petit'),
#  (31, u'Dante', None, u'gros'),
#  (94, u'Zola', u'Emile', u'moyen'),
#  (38, u'Montaigne', u'Michel de', u'petit'),
#  (96, u'Wilde', u'Oscar', u'petit'),
#  (97, u'Vigny', u'Alfred de', u'petit'),
#  (40, u'Moliere', None, u'petit'),
#  (41, u'Gauthier', u'Theophile', u'petit')]

# %%
# %%sql DROP TABLE IF EXISTS vins2;
#
# CREATE TABLE vins2 AS
# SELECT DISTINCT NV, CRU, DEGRE, MILL
# FROM MASTER2 WHERE NV IS NOT NULL;
#
#
# SELECT *
# FROM vins2;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(1, u'Mercurey', 11.5, 1980),
#  (2, u'Julienas', 11.3, 1974),
#  (3, u'Savigny les Beaunes', 12.1, 1978),
#  (4, u'Mercurey', 10.9, 1980),
#  (5, u'Pommard', 11.7, 1976),
#  (6, u'Mercurey', 11.2, 1981),
#  (7, u'Grands Echezeaux', 11.7, 1968),
#  (8, u'Cotes de Beaune Villages', 12.3, 1975),
#  (9, u'Chapelle Chambertin', 11.9, 1973),
#  (10, u'Beaujolais Villages', 11.8, 1979),
#  (11, u'Sylvaner', 11.2, 1982),
#  (12, u'Gentil', 10.7, 1975),
#  (13, u'Cotes du Rhone', 12.3, 1968),
#  (14, u'Chateau Chalon', 10.9, 1978),
#  (15, u'Cote de Brouilly', 11.9, 1973),
#  (16, u'Meursault', 12.1, 1980),
#  (17, u'Meursault', 11.4, 1975),
#  (18, u'Chambolle Musigny', 12.3, 1968),
#  (19, u'Clos du roi', 11.2, 1972),
#  (20, u'Cote de Brouilly', 12.1, 1980),
#  (21, u'Cotes de Nuits', None, 1978),
#  (22, u'Savigny les Beaunes', None, 1974),
#  (23, u'Pommard', None, 1972),
#  (24, u'Cotes de Beaune Villages', 12.1, 1971),
#  (91, u'Cassis', 11, 1979),
#  (92, u'Coteaux de Pierevert', None, 1967),
#  (93, u'Blanquette de Limoux', None, 1978),
#  (94, u'Cotes du Rousillon', None, 1978),
#  (95, u'Cotes du Rousillon', 12, 1978),
#  (96, u'Saint Chinian', 11, 1976),
#  (97, u'Saint Chinian', 11, 1976),
#  (98, u'Corbieres', 10, 1978),
#  (99, u'Cote Rotie', 13, 1994),
#  (100, u'Seyssel', 11, 1974),
#  (101, u'Saint Veran', 12.5, 1973),
#  (107, u'Sancerre', 14, 1998)]

# %%
# %%sql DROP TABLE IF EXISTS lieu;
#
# CREATE TABLE lieu AS
# SELECT DISTINCT LIEU, REGION
# FROM MASTER2 WHERE LIEU IS NOT NULL;
#
#
# SELECT *
# FROM lieu;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(u'BORDEAUX', u' NOUVELLE-AQUITAINE'),
#  (u'PARIS', u' \xceLE-DE-FRANCE'),
#  (u'RENNES', u' BRETAGNE'),
#  (u'LYON', u'  AUVERGNE-RH\xd4NE-ALPES'),
#  (u'NICE', u" PROVENCE-ALPES-C\xd4TE D'AZUR"),
#  (u'MERCUREY', u' BOURGOGNE-FRANCHE-COMT\xc9'),
#  (u'TOULOUSE', u' OCCITANIE'),
#  (u'SENS', u' BOURGOGNE-FRANCHE-COMT\xc9'),
#  (u'LILLE', u' HAUTS-DE-FRANCE'),
#  (u'NANCY', u' GRAND EST'),
#  (u'CANNES', u" PROVENCE-ALPES-C\xd4TE D'AZUR"),
#  (u'TOULON', u" PROVENCE-ALPES-C\xd4TE D'AZUR"),
#  (u'CHALON SUR SAONE', u' BOURGOGNE-FRANCHE-COMT\xc9'),
#  (u'ROCQUENCOURT', u' \xceLE-DE-FRANCE'),
#  (u'PARLY', u' BOURGOGNE-FRANCHE-COMT\xc9'),
#  (u'LE CHESNAY', u' \xceLE-DE-FRANCE'),
#  (u'CAEN', u' NORMANDIE'),
#  (u'DIJON', u' BOURGOGNE-FRANCHE-COMT\xc9')]

# %%
# %%sql DROP TABLE IF EXISTS achats;
#
# CREATE TABLE achats AS
# SELECT NB, NV, LIEU, DATES, QTE
# FROM MASTER2 WHERE NB IS NOT NULL AND NV IS NOT NULL;
#
#
# SELECT *
# FROM achats;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(2, 1, u'BORDEAUX', u'1977-11-02', 33),
#  (44, 1, u'PARIS', u'2015-10-16', 1),
#  (45, 1, u'RENNES', u'1983-12-31', 1),
#  (48, 2, u'LYON', u'1983-12-25', 2),
#  (7, 3, u'NICE', u'1978-11-01', 6),
#  (49, 3, u'MERCUREY', u'1987-12-24', 5),
#  (8, 4, u'TOULOUSE', u'1982-11-05', 12),
#  (44, 4, u'PARIS', u'2015-10-16', 6),
#  (50, 4, u'SENS', u'1981-06-29', 4),
#  (2, 5, u'MERCUREY', u'1984-11-04', 50),
#  (52, 5, u'LILLE', u'1983-06-29', 5),
#  (3, 6, u'NANCY', u'1978-01-21', 36),
#  (4, 7, u'PARIS', u'1987-09-19', 24),
#  (58, 7, u'CANNES', u'1987-04-28', 7),
#  (1, 8, u'PARIS', u'1982-09-15', 78),
#  (9, 8, u'LILLE', u'1979-11-01', 10),
#  (60, 8, u'TOULON', u'1980-05-12', 8),
#  (5, 9, u'LYON', u'1982-03-26', 20),
#  (40, 100, u'NANCY', u'1982-11-05', 11),
#  (41, 100, u'CANNES', u'1982-11-04', 10)]

# %% [markdown]
# # PART II: SQL QUERIES
#
# In the second part of this TP you will create SQL queries to retrieve information from the database.
#
# **Important:**
#
# - You MUST use the normalized tables created in previous steps.
#   - The normalized tables will also be used in TP3.
# - Do NOT use **Master1** and **Master2** in your queries.

# %% [markdown]
# #### Exercise 2.1
#
# What are the different types of clients (buveurs) by volume of purchases?

# %%
# %%sql SELECT DISTINCT(TYPE) as Types_of_buveurs
# FROM acheteurs;
# Out:
#  * sqlite:///wine.db
# Done.
# [(u'petit',), (u'moyen',), (u'gros',)]

# %% [markdown]
# #### Exercise 2.2
#
# What regions produce Pommard or Brouilly?

# %%
# %%sql
# SELECT CRU, REGION
# FROM produits JOIN vins1 ON produits.NV=vins1.NV
# JOIN producteur on producteur.NP=produits.NP
# WHERE CRU="Pommard"  or CRU="Brouilly";
# Out:
#  * sqlite:///wine.db
# Done.
# [(u'Pommard', u'Bourgogne'),
#  (u'Pommard', u'Rhone'),
#  (u'Brouilly', u'Bourgogne')]

# %% [markdown]
# #### Exercise 2.3
#
# What regions produce Pommard and Brouilly?

# %%
# %%sql
# SELECT REGION
# FROM produits JOIN vins1 ON produits.NV=vins1.NV
# JOIN producteur on producteur.NP=produits.NP
# WHERE CRU="Pommard"
# INTERSECT
# SELECT REGION
# FROM produits JOIN vins1 ON produits.NV=vins1.NV
# JOIN producteur on producteur.NP=produits.NP
# WHERE CRU="Brouilly";
# Out:
#  * sqlite:///wine.db
# Done.
# [(u'Bourgogne',)]

# %% [markdown]
# #### Exercise 2.4
#
# Get the number of wines bought by CRU and Millésime

# %%
# %%sql
# SELECT CRU,MILL,SUM(QTE)
# FROM achats JOIN vins2 on achats.NV=vins2.NV
# GROUP BY CRU, MILL
# Out:
#  * sqlite:///wine.db
# Done.
# [(u'Arbois', 1980, 8),
#  (u'Auxey Duresses', 1914, 80),
#  (u'Beaujolais Primeur', 1983, 7),
#  (u'Beaujolais Villages', 1975, 10),
#  (u'Beaujolais Villages', 1976, 120),
#  (u'Beaujolais Villages', 1978, 130),
#  (u'Beaujolais Villages', 1979, 520),
#  (u'Chapelle Chambertin', 1973, 30),
#  (u'Chateau Corton Grancey', 1980, 4),
#  (u'Chenas', 1984, 1),
#  (u'Clairette de Die', 1976, 5),
#  (u'Cornas', 1980, 25),
#  (u'Cote de Brouilly', 1980, 23),
#  (u'Coteaux du Tricastin', 1974, 1),
#  (u'Coteaux du Tricastin', 1978, 12),
#  (u'Cotes de Beaune Villages', 1971, 14),
#  (u'Cotes de Beaune Villages', 1975, 96),
#  (u'Cotes de Nuits', 1978, 21),
#  (u'Cotes de Provence', 1980, 18),
#  (u'Etoile', 1980, 9),
#  (u'Fleurie', 1980, 7),
#  (u'Gentil', 1975, 36),
#  (u'Gigondas', 1978, 5),
#  (u'Grands Echezeaux', 1968, 31),
#  (u'Julienas', 1974, 2),
#  (u'Mercurey', 1980, 57),
#  (u'Mercurey', 1981, 36),
#  (u'Meursault', 1980, 2),
#  (u'Monthelie', 1968, 106),
#  (u'Pommard', 1972, 23),
#  (u'Pommard', 1976, 55),
#  (u'Pouilly Vinzelles', 1968, 10),
#  (u'Rasteau', 1980, 15),
#  (u'Richebourg', 1943, 72),
#  (u'Saint Amour', 1974, 80),
#  (u'Saint Amour', 1980, 14),
#  (u'Savigny les Beaunes', 1974, 44),
#  (u'Savigny les Beaunes', 1977, 7),
#  (u'Savigny les Beaunes', 1978, 11),
#  (u'Seyssel', 1974, 24),
#  (u'Seyssel', 1980, 21),
#  (u'Tavel', 1980, 33),
#  (u'Volnay', 1980, 5)]

# %% [markdown]
# #### Exercise 2.5
#
# Retrieve the wine number (NV) of wines produced by more than three producers

# %%
# %%sql
# SELECT NV, COUNT(DISTINCT(NP)) as Number_of_producers
# FROM produits GROUP BY NV HAVING COUNT(DISTINCT(NP))>3;
# Out:
#  * sqlite:///wine.db
# Done.
# [(45, 5), (78, 5), (89, 4), (98, 5)]

# %% [markdown]
# #### Exercise 2.6
#
# Which producers have not produced any wine?

# %%
# %%sql
# SELECT p1.NP, p1.NOM, p1.PRENOM
# FROM producteur as p1
# EXCEPT
# SELECT p2.NP, p2.NOM, p2.PRENOM
# FROM producteur as p2
# JOIN produits on p2.NP=produits.NP
# Out:
#  * sqlite:///wine.db
# Done.
# [(3, u'Six', u'Paul'),
#  (6, u'Marmagne', u'Bernard'),
#  (8, u"Lioger d'Harduy", u'Gabriel'),
#  (16, u'Barbin', u'Bernard'),
#  (17, u'Faiveley', u'Guy'),
#  (18, u'Tramier', u'Jean'),
#  (19, u'Dupaquier', u'Roger'),
#  (20, u'Lamy', u'Jean'),
#  (21, u'Cornu', u'Edmond'),
#  (26, u'Violot', u'Gilbert'),
#  (28, u'Monnier', u'Rene'),
#  (29, u'de Suremain', u'Robert'),
#  (31, u'Prudhon', u'Henri'),
#  (32, u'Mestre', u'Philippe'),
#  (33, u'Prieur', u'Guy'),
#  (34, u'Monnier', u'Rene'),
#  (37, u'Delagrange Bachelet', None),
#  (39, u'de Suremin', u'Hugues'),
#  (41, u'Juillot', u'Michel'),
#  (44, u'Feyveley', None),
#  (47, u'Thenard', None),
#  (48, u'Flamand', None),
#  (49, u'Guillot', u'Pierre'),
#  (51, u'Simonet', u'Leon'),
#  (53, u'Cooperative', None),
#  (57, u'Desmules', u'Pierre'),
#  (58, u'Joubert', u'Claude'),
#  (61, u'Champier', u'Charles'),
#  (62, u'Champagnon', u'Louis'),
#  (66, u'Cooperative', None),
#  (77, u'Tissot', u'Andre'),
#  (83, u'Goy', None),
#  (91, u'Chave', u'Gerard'),
#  (92, u'De Boissieu', None),
#  (94, u'Grippat', u'Jean Louis'),
#  (96, u'Boisson', u'Jean Pierre'),
#  (97, u'Quiot', u'Pierre'),
#  (100, u'Bernard', u'Georges'),
#  (101, u'Verdan', u'Antoine'),
#  (102, u'Cooperative', None),
#  (103, u'Coulouvrat', u'Michel'),
#  (104, u'Rabasse Chavarin', u'Abel'),
#  (105, u'Roux', u'Charles'),
#  (106, u'Alary', None),
#  (108, u'Archimbaud', u'Jean'),
#  (109, u'Rey', u'Marcel'),
#  (110, u'Cooperative', None),
#  (111, u'Zafiropulo', u'Costa'),
#  (112, u'Prebost', u'Gaston'),
#  (113, u'Gomez', u'Rene'),
#  (114, u'Brunet', u'Georges'),
#  (115, u'Bordonado', u'Raymond'),
#  (116, u'Imbert', u'Christian'),
#  (117, u'Cooperative', None),
#  (118, u'Cooperative', None),
#  (119, u'Cooperative', None),
#  (121, u'Cooperative', None),
#  (122, u'Dupuy', u'Charles'),
#  (123, u'Laurent', u'Pierre'),
#  (124, u'Daurat Fort', u'Robert'),
#  (125, u'Baldes', u'Jean'),
#  (126, u'Jouffreau', u'Jean'),
#  (127, u'Brumont', u'Alban'),
#  (129, u'Barrere', u'Alfred')]

# %% [markdown]
# #### Exercise 2.7
#
# What clients (buveurs) have bought at least one wine from 1980?

# %%
# %%sql DROP VIEW IF EXISTS question7;
# CREATE VIEW question7 AS
# SELECT DISTINCT a2.NB, a2.NOM, a2.PRENOM
# FROM achats as a1 JOIN acheteurs as a2 ON a1.NB=a2.NB
# JOIN vins2 on vins2.NV=a1.NV
# WHERE vins2.MILL=1980;
# SELECT * FROM question7;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(2, u'Artaud', u'Antonin'),
#  (44, u'Gide', u'Andre'),
#  (45, u'Giono', u'Jean'),
#  (8, u'Aragon', u'Louis'),
#  (50, u'Lautreamont', None),
#  (61, u'Mallarme', u'Stephane')]

# %% [markdown]
# #### Exercise 2.8
#
# What clients (buveurs) have NOT bought any wine from 1980?

# %%
# %%sql DROP VIEW IF EXISTS question8;
# CREATE VIEW question8 AS
# SELECT DISTINCT a2.NB, a2.NOM, a2.PRENOM
# FROM achats as a1 JOIN acheteurs as a2 ON a1.NB=a2.NB
# JOIN vins2 on vins2.NV=a1.NV
# EXCEPT
# SELECT DISTINCT NB, NOM, PRENOM
# FROM question7;
# SELECT * FROM question8;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(1, u'Aristote', None),
#  (3, u'Aron', u'Raymond'),
#  (4, u'Apollinaire', u'Guillaume'),
#  (5, u'Audiberti', u'Jacques'),
#  (6, u'Arrabal', u'Fernando'),
#  (7, u'Anouilh', u'Jean'),
#  (9, u'Ajar', u'Emile'),
#  (10, u'Andersen', u'Yann'),
#  (12, u'Bataille', u'Georges'),
#  (14, u'Bory', u'Jean Louis'),
#  (15, u'Baudelaire', u'Charles'),
#  (17, u'Camus', u'Albert'),
#  (19, u'Ciceron', None),
#  (22, u'Cocteau', u'Jean'),
#  (24, u'Courrier', u'Paul Louis'),
#  (26, u'Diderot', u'Denis'),
#  (28, u'Dostoievsky', u'Fiodor'),
#  (30, u'La Fontaine', u'Jean de'),
#  (31, u'Dante', None),
#  (33, u'Flaubert', u'Gustave'),
#  (38, u'Montaigne', u'Michel de'),
#  (40, u'Moliere', None),
#  (41, u'Gauthier', u'Theophile'),
#  (48, u'Hardy', u'Thomas'),
#  (49, u'Kafka', u'Franz'),
#  (52, u'Carroll', u'Lewis'),
#  (58, u'Marivaux', u'Pierre Carlet de Chamblain de'),
#  (60, u'Ovide', None),
#  (62, u'Proust', u'Marcel'),
#  (75, u'Ronsard', u'Pierre'),
#  (80, u'Sand', u'Georges'),
#  (82, u'Roussel', u'Rene'),
#  (92, u'Verne', u'Jules'),
#  (94, u'Zola', u'Emile'),
#  (96, u'Wilde', u'Oscar'),
#  (97, u'Vigny', u'Alfred de'),
#  (100, u'Woolf', u'Virginia')]

# %% [markdown]
# #### Exercise 2.9
#
# What clients (buveurs) have bought ONLY wines from 1980?

# %%
# %%sql DROP VIEW IF EXISTS question9;
# CREATE VIEW question9 AS
# SELECT DISTINCT NB, NOM, PRENOM
# FROM question7
# EXCEPT
# SELECT DISTINCT a2.NB, a2.NOM, a2.PRENOM
# FROM achats as a1 JOIN acheteurs as a2 ON a1.NB=a2.NB
# JOIN vins2 on vins2.NV=a1.NV
# WHERE vins2.MILL!=1980;
# SELECT * FROM question9;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(44, u'Gide', u'Andre'), (45, u'Giono', u'Jean'), (50, u'Lautreamont', None)]

# %% [markdown]
# #### Exercise 2.10
#
# List all wines from 1980

# %%
# %%sql DROP VIEW IF EXISTS question10;
# CREATE VIEW question10 AS
# SELECT NV, CRU, MILL, DEGRE
# FROM vins1 WHERE MILL=1980;
# SELECT * FROM question10;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(1, u'Mercurey', 1980, 11.5),
#  (4, u'Mercurey', 1980, 10.9),
#  (16, u'Meursault', 1980, 12.1),
#  (20, u'Cote de Brouilly', 1980, 12.1),
#  (26, u'Chateau Corton Grancey', 1980, None),
#  (28, u'Volnay', 1980, 11),
#  (43, u'Fleurie', 1980, 11.4),
#  (74, u'Arbois', 1980, 12),
#  (78, u'Etoile', 1980, 12),
#  (79, u'Seyssel', 1980, 11),
#  (80, u'Seyssel', 1980, 11),
#  (81, u'Cornas', 1980, 11.1),
#  (82, u'Cornas', 1980, 11),
#  (83, u'Saint Amour', 1980, 10),
#  (84, u'Rasteau', 1980, 10),
#  (85, u'Tavel', 1980, 11),
#  (86, u'Tavel', 1980, 11),
#  (87, u'Cotes de Provence', 1980, None)]

# %% [markdown]
# #### Exercise 2.11
#
# What are the wines from 1980 bought by NB=2?

# %%
# %%sql DROP VIEW IF EXISTS question11;
# CREATE VIEW question11 AS
# SELECT achats.NV, CRU, MILL, DEGRE
# FROM achats JOIN question10 ON question10.NV=achats.NV WHERE NB=2;
# SELECT * FROM question11;
# Out:
#  * sqlite:///wine.db
# Done.
# Done.
# Done.
# [(1, u'Mercurey', 1980, 11.5)]

# %% [markdown]
# #### Exercise 2.12
#
# What clients (buveurs) have bought ALL the wines from 1980?

# %%
# %%sql
# SELECT DISTINCT acheteurs.NB, acheteurs.NOM, acheteurs.PRENOM
# FROM acheteurs JOIN achats as a1 ON a1.NB=acheteurs.NB
# WHERE NOT EXISTS
# (SELECT question10.NV FROM question10
# EXCEPT
# SELECT a2.NV FROM achats as a2
# WHERE a2.NB=a1.NB);
# Out:
#  * sqlite:///wine.db
# Done.
# [(44, u'Gide', u'Andre')]
